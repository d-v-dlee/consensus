# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '/Users/david/statsbomb/projects/consensus/scripts')

# %%
# load csv
df = pd.read_csv('../example_data/deg.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#          TARGET.USI  ENSG00000129194.6  ENSG00000172236.15  ENSG00000196557.9  \
# 0  TARGET-20-PADZCG          -0.607224            3.188884          -4.476058
# 1  TARGET-20-PAEAKL          -0.383182           -0.291629          -1.611780
# 2  TARGET-20-PAEERJ           0.084168            3.492654          -4.761442
# 3  TARGET-20-PAEFGR           2.063610            7.265777           0.142965
# 4  TARGET-20-PAEFGT          -2.390698            4.891460          -5.062832
#
#    ENSG00000163106.9  ENSG00000134569.8  ENSG00000170893.3  ENSG00000182809.9  \
# 0          -2.430738          -1.248229          -4.055846          -0.557989
# 1          -7.168604          -4.962724          -2.723807           3.326062
# 2          -2.851090          -1.953077           0.067788           0.517088
# 3           1.673942           3.087568           5.527616           3.217842
# 4          -3.037558          -2.678174          -0.901846           1.501792
#
#    ENSG00000007516.12  ENSG00000144668.10    ...     ENSG00000196562.13  \
# 0           -0.803654            3.813199    ...               3.232680
# 1           -2.101566            0.350912    ...               5.659788
# 2           -0.475922            3.085052    ...               3.369433
# 3            2.320031            4.571286    ...               5.376250
# 4           -0.166185            1.820669    ...               1.076196
#
#    ENSG00000162551.12  ENSG00000061676.13  ENSG00000010610.8  \
# 0            4.698256            0.486378           5.297164
# 1            0.379049           -4.128217           7.294752
# 2           -6.272635           -1.736242           4.918502
# 3           -0.899780            0.253798           2.199050
# 4           -7.168604           -0.522896           2.205367
#
#    ENSG00000187997.10  ENSG00000085733.14  ENSG00000183914.13  \
# 0           -0.598901            0.087973           -3.349459
# 1           -3.305573           -1.668245           -5.277119
# 2           -2.621256            0.397665           -4.761442
# 3           -3.252679           -2.046506           -4.782271
# 4           -4.594158           -0.386703           -2.678174
#
#    ENSG00000224739.2  ENSG00000179097.5  Low Risk
# 0           4.300482          -3.527576       0.0
# 1          -1.919197          -7.168604       0.0
# 2           2.517864           0.708857       0.0
# 3          -0.981142          -4.160133       1.0
# 4           4.344944           0.551276       0.0
#
# [5 rows x 1986 columns]

# %%
X = df.iloc[:, 1:-1]
y = df.iloc[:, -1]

print(X.shape)
print(y.shape)
# Out:
# (137, 1984)
# (137,)

# %%
from consensus import ConsensusML

# %%
# call class
cml = ConsensusML()

# %%
# input data, creates train and test data
cml.data_input(X, y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

lasso = LogisticRegression(penalty='l1', solver='saga', max_iter=10000)
rf = RandomForestClassifier(n_estimators=1000, max_depth=20, random_state=8, n_jobs=-1)
xgb = XGBClassifier(learning_rate = 0.01, max_depth = 3, n_estimators = 700, random_state=8, n_jobs=-1)

cml.model_input(lasso, rf, xgb, ["Lasso", 'Random Forest', 'XGBoost'])

# %%
cml.get_performances()
cml.get_weights()

# %%
model_dict = cml.model_per
